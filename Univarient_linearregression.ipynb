# %% [markdown]
# <a href="https://colab.research.google.com/github/MRUDHULA-DUNNA/FML-LAB/blob/main/Univarient_linearregression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
data=pd.read_csv("boston.csv")
data.head()

# %%
X=data.drop('medv',axis=1).values
Y=data['medv'].values

# %%
X_rooms = X[:,5]
print(X_rooms)
type(X_rooms),type(Y)
X_rooms.shape,Y.shape

# %%
X_rooms=X_rooms.reshape(-1,1)
#print(X_rooms)
Y=Y.reshape(-1,1)
#print(Y)

# %%
X_rooms.shape,Y.shape
#print(X_rooms)
#print(Y)
# Out:
# ((506, 1), (506, 1))

# %%
plt.scatter(X_rooms,Y)
plt.xlabel('Number of rooms present')
plt.ylabel('value of house')
plt.show()

# %%
reg = linear_model.LinearRegression()
reg.fit(X_rooms, Y)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_absolute_error,r2_score,mean_squared_error
Y_pred = reg.predict(X_rooms)
print(f'MAE = {mean_absolute_error(Y,Y_pred)}')
print(f'MSE = {mean_squared_error(Y, Y_pred)}')
print(f'RMSE = {np.sqrt(mean_squared_error(Y, Y_pred))}')
print(f'R_2 = {r2_score(Y, Y_pred)}')
# Out:
# MAE = 4.4477729015322325
# MSE = 43.60055177116956
# RMSE = 6.603071389222561
# R_2 = 0.48352545599133423

# %%
prediction_space = np.linspace(min(X_rooms), max(X_rooms)).reshape(-1,1)

# %%
plt.scatter(X_rooms, Y, color='green')
plt.plot(X_rooms, reg.predict(X_rooms), color='red', linewidth=3)
plt.show()

# %%
plt.scatter(X_rooms, Y, color='green')
plt.plot(prediction_space, reg.predict(prediction_space), color='black', linewidth=3)
plt.show()
